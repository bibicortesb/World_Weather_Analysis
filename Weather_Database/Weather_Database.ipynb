# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 728

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fe5fd8d045b0d99faddb0baa7038d9a6

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]     
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | atar
# Processing Record 3 of Set 1 | ixtapa
# Processing Record 4 of Set 1 | kupang
# Processing Record 5 of Set 1 | honningsvag
# Processing Record 6 of Set 1 | havelock
# Processing Record 7 of Set 1 | poum
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | kleck
# City not found. Skipping...
# Processing Record 10 of Set 1 | ngunguru
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | nivala
# Processing Record 13 of Set 1 | severo-kurilsk
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | brest
# Processing Record 19 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | isangel
# Processing Record 22 of Set 1 | jalu
# Processing Record 23 of Set 1 | margate
# Processing Record 24 of Set 1 | castro
# Processing Record 25 of Set 1 | walvis bay
# Processing Record 26 of Set 1 | khuzhir
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | aklavik
# Processing Record 30 of Set 1 | sur
# Processing Record 31 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 32 of Set 1 | galgani
# City not found. Skipping...
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | zlynka
# Processing Record 35 of Set 1 | maldonado
# Processing Record 36 of Set 1 | tura
# Processing Record 37 of Set 1 | concepcion
# Processing Record 38 of Set 1 | fukue
# Processing Record 39 of Set 1 | krasni okny
# Processing Record 40 of Set 1 | hualmay
# Processing Record 41 of Set 1 | torrington
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | saint-francois
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | saskylakh
# Processing Record 46 of Set 1 | cayenne
# Processing Record 47 of Set 1 | kaitangata
# Processing Record 48 of Set 1 | yulara
# Processing Record 49 of Set 1 | viransehir
# Processing Record 50 of Set 1 | kodaikanal
# Processing Record 1 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 2 | sitka
# Processing Record 3 of Set 2 | chalon-sur-saone
# Processing Record 4 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 2 | husavik
# Processing Record 8 of Set 2 | ust-kut
# Processing Record 9 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 2 | chuy
# Processing Record 11 of Set 2 | waipawa
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | nome
# Processing Record 14 of Set 2 | hilo
# Processing Record 15 of Set 2 | guerrero negro
# Processing Record 16 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 2 | alofi
# Processing Record 18 of Set 2 | ormara
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | peniche
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | burnie
# Processing Record 23 of Set 2 | aswan
# Processing Record 24 of Set 2 | port hedland
# Processing Record 25 of Set 2 | hobart
# Processing Record 26 of Set 2 | mahebourg
# Processing Record 27 of Set 2 | shenjiamen
# Processing Record 28 of Set 2 | manta
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | zorgo
# Processing Record 31 of Set 2 | mataura
# Processing Record 32 of Set 2 | tongren
# Processing Record 33 of Set 2 | gizo
# Processing Record 34 of Set 2 | newport
# Processing Record 35 of Set 2 | nanortalik
# Processing Record 36 of Set 2 | kashan
# Processing Record 37 of Set 2 | el fuerte
# Processing Record 38 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 39 of Set 2 | iqaluit
# Processing Record 40 of Set 2 | san quintin
# Processing Record 41 of Set 2 | bengkulu
# Processing Record 42 of Set 2 | cidreira
# Processing Record 43 of Set 2 | rikitea
# Processing Record 44 of Set 2 | bluff
# Processing Record 45 of Set 2 | mackay
# Processing Record 46 of Set 2 | ivybridge
# Processing Record 47 of Set 2 | udachnyy
# Processing Record 48 of Set 2 | new norfolk
# Processing Record 49 of Set 2 | koumac
# Processing Record 50 of Set 2 | moree
# Processing Record 1 of Set 3 | gorele
# Processing Record 2 of Set 3 | penzance
# Processing Record 3 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 4 of Set 3 | khatanga
# Processing Record 5 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | lata
# Processing Record 8 of Set 3 | kavaratti
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | tulum
# Processing Record 11 of Set 3 | omsukchan
# Processing Record 12 of Set 3 | perigueux
# Processing Record 13 of Set 3 | cairo
# Processing Record 14 of Set 3 | hami
# Processing Record 15 of Set 3 | tuktoyaktuk
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | ulaangom
# Processing Record 18 of Set 3 | east london
# Processing Record 19 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 3 | xiangdong
# City not found. Skipping...
# Processing Record 21 of Set 3 | neuss
# Processing Record 22 of Set 3 | baghdad
# Processing Record 23 of Set 3 | ahipara
# Processing Record 24 of Set 3 | tiksi
# Processing Record 25 of Set 3 | evensk
# Processing Record 26 of Set 3 | saldanha
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | shingu
# Processing Record 29 of Set 3 | cape town
# Processing Record 30 of Set 3 | labuhan
# Processing Record 31 of Set 3 | elizabethton
# Processing Record 32 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 33 of Set 3 | dikson
# Processing Record 34 of Set 3 | tiznit
# Processing Record 35 of Set 3 | port lincoln
# Processing Record 36 of Set 3 | hanzhong
# Processing Record 37 of Set 3 | yellowknife
# Processing Record 38 of Set 3 | hambantota
# Processing Record 39 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 3 | qovlar
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | buchanan
# Processing Record 43 of Set 3 | saint-philippe
# Processing Record 44 of Set 3 | mar del plata
# Processing Record 45 of Set 3 | talnakh
# Processing Record 46 of Set 3 | saint george
# Processing Record 47 of Set 3 | khasan
# Processing Record 48 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 3 | comarapa
# Processing Record 50 of Set 3 | yumen
# Processing Record 1 of Set 4 | atuona
# Processing Record 2 of Set 4 | balad
# Processing Record 3 of Set 4 | lavrentiya
# Processing Record 4 of Set 4 | anamur
# Processing Record 5 of Set 4 | bonavista
# Processing Record 6 of Set 4 | qaanaaq
# Processing Record 7 of Set 4 | eagle pass
# Processing Record 8 of Set 4 | muhammadabad
# Processing Record 9 of Set 4 | jutai
# Processing Record 10 of Set 4 | butaritari
# Processing Record 11 of Set 4 | daru
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | rio branco do sul
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | jarjis
# City not found. Skipping...
# Processing Record 16 of Set 4 | richards bay
# Processing Record 17 of Set 4 | nishihara
# Processing Record 18 of Set 4 | albany
# Processing Record 19 of Set 4 | vera cruz
# Processing Record 20 of Set 4 | borazjan
# Processing Record 21 of Set 4 | canyon lake
# Processing Record 22 of Set 4 | lac du bonnet
# Processing Record 23 of Set 4 | ust-kuyga
# Processing Record 24 of Set 4 | gamba
# Processing Record 25 of Set 4 | salur
# Processing Record 26 of Set 4 | marzuq
# Processing Record 27 of Set 4 | pevek
# Processing Record 28 of Set 4 | misratah
# Processing Record 29 of Set 4 | butte
# Processing Record 30 of Set 4 | faanui
# Processing Record 31 of Set 4 | bergen
# Processing Record 32 of Set 4 | qaqortoq
# Processing Record 33 of Set 4 | winneba
# Processing Record 34 of Set 4 | karratha
# Processing Record 35 of Set 4 | taltal
# Processing Record 36 of Set 4 | luderitz
# Processing Record 37 of Set 4 | pangai
# Processing Record 38 of Set 4 | fortuna
# Processing Record 39 of Set 4 | leshukonskoye
# Processing Record 40 of Set 4 | jamestown
# Processing Record 41 of Set 4 | barrow
# Processing Record 42 of Set 4 | pierre
# Processing Record 43 of Set 4 | strezhevoy
# Processing Record 44 of Set 4 | puliyankudi
# Processing Record 45 of Set 4 | bilma
# Processing Record 46 of Set 4 | asyut
# Processing Record 47 of Set 4 | nemuro
# Processing Record 48 of Set 4 | udomlya
# Processing Record 49 of Set 4 | charcas
# Processing Record 50 of Set 4 | tasiilaq
# Processing Record 1 of Set 5 | port elizabeth
# Processing Record 2 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | aitape
# Processing Record 5 of Set 5 | a
# City not found. Skipping...
# Processing Record 6 of Set 5 | chokurdakh
# Processing Record 7 of Set 5 | ondangwa
# Processing Record 8 of Set 5 | makakilo city
# Processing Record 9 of Set 5 | nuuk
# Processing Record 10 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 5 | mokhsogollokh
# Processing Record 12 of Set 5 | porto novo
# Processing Record 13 of Set 5 | zhaoyuan
# Processing Record 14 of Set 5 | brigantine
# Processing Record 15 of Set 5 | victoria
# Processing Record 16 of Set 5 | leningradskiy
# Processing Record 17 of Set 5 | sudbury
# Processing Record 18 of Set 5 | padang
# Processing Record 19 of Set 5 | jitra
# Processing Record 20 of Set 5 | grindavik
# Processing Record 21 of Set 5 | ibra
# Processing Record 22 of Set 5 | nova serrana
# Processing Record 23 of Set 5 | narsaq
# Processing Record 24 of Set 5 | erenhot
# Processing Record 25 of Set 5 | teguise
# Processing Record 26 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 5 | haines junction
# Processing Record 28 of Set 5 | hamilton
# Processing Record 29 of Set 5 | pasni
# Processing Record 30 of Set 5 | ponta do sol
# Processing Record 31 of Set 5 | fairbanks
# Processing Record 32 of Set 5 | ishigaki
# Processing Record 33 of Set 5 | taoudenni
# Processing Record 34 of Set 5 | kaeo
# Processing Record 35 of Set 5 | maningrida
# Processing Record 36 of Set 5 | hofn
# Processing Record 37 of Set 5 | caravelas
# Processing Record 38 of Set 5 | la ronge
# Processing Record 39 of Set 5 | okitipupa
# Processing Record 40 of Set 5 | vanimo
# Processing Record 41 of Set 5 | portland
# Processing Record 42 of Set 5 | mabaruma
# Processing Record 43 of Set 5 | san rafael del sur
# Processing Record 44 of Set 5 | zharkent
# Processing Record 45 of Set 5 | breves
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | ostrovnoy
# Processing Record 48 of Set 5 | bida
# Processing Record 49 of Set 5 | belo jardim
# Processing Record 50 of Set 5 | nanakuli
# Processing Record 1 of Set 6 | hithadhoo
# Processing Record 2 of Set 6 | kandrian
# Processing Record 3 of Set 6 | belmonte
# Processing Record 4 of Set 6 | lemesos
# City not found. Skipping...
# Processing Record 5 of Set 6 | eenhana
# Processing Record 6 of Set 6 | bethel
# Processing Record 7 of Set 6 | vestmannaeyjar
# Processing Record 8 of Set 6 | axim
# Processing Record 9 of Set 6 | lagoa
# Processing Record 10 of Set 6 | souillac
# Processing Record 11 of Set 6 | lebu
# Processing Record 12 of Set 6 | nikolskoye
# Processing Record 13 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 14 of Set 6 | mount gambier
# Processing Record 15 of Set 6 | shimoda
# Processing Record 16 of Set 6 | jimo
# Processing Record 17 of Set 6 | sao filipe
# Processing Record 18 of Set 6 | carnarvon
# Processing Record 19 of Set 6 | kahului
# Processing Record 20 of Set 6 | tungkang
# City not found. Skipping...
# Processing Record 21 of Set 6 | descalvado
# Processing Record 22 of Set 6 | north bend
# Processing Record 23 of Set 6 | okha
# Processing Record 24 of Set 6 | cherskiy
# Processing Record 25 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 6 | santa rosa
# Processing Record 27 of Set 6 | mahenge
# Processing Record 28 of Set 6 | hailakandi
# Processing Record 29 of Set 6 | myaundzha
# Processing Record 30 of Set 6 | cacak
# Processing Record 31 of Set 6 | great bend
# Processing Record 32 of Set 6 | avera
# Processing Record 33 of Set 6 | leh
# Processing Record 34 of Set 6 | eureka
# Processing Record 35 of Set 6 | devils lake
# Processing Record 36 of Set 6 | bemidji
# Processing Record 37 of Set 6 | marathon
# Processing Record 38 of Set 6 | naze
# Processing Record 39 of Set 6 | sao lourenco do sul
# Processing Record 40 of Set 6 | salto de agua
# Processing Record 41 of Set 6 | sena madureira
# Processing Record 42 of Set 6 | sabang
# Processing Record 43 of Set 6 | saint-louis
# Processing Record 44 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 45 of Set 6 | mnogovershinnyy
# Processing Record 46 of Set 6 | anadyr
# Processing Record 47 of Set 6 | la union
# Processing Record 48 of Set 6 | necochea
# Processing Record 49 of Set 6 | pimentel
# Processing Record 50 of Set 6 | katangli
# Processing Record 1 of Set 7 | haibowan
# City not found. Skipping...
# Processing Record 2 of Set 7 | estevan
# Processing Record 3 of Set 7 | nobres
# Processing Record 4 of Set 7 | nisia floresta
# Processing Record 5 of Set 7 | airai
# Processing Record 6 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 7 | yerbogachen
# Processing Record 8 of Set 7 | vestmanna
# Processing Record 9 of Set 7 | gubkinskiy
# Processing Record 10 of Set 7 | namibe
# Processing Record 11 of Set 7 | sili
# Processing Record 12 of Set 7 | xuanhua
# Processing Record 13 of Set 7 | touros
# Processing Record 14 of Set 7 | ilfracombe
# Processing Record 15 of Set 7 | tir pol
# City not found. Skipping...
# Processing Record 16 of Set 7 | potong
# Processing Record 17 of Set 7 | codrington
# Processing Record 18 of Set 7 | quang ngai
# Processing Record 19 of Set 7 | wanaka
# Processing Record 20 of Set 7 | virginia beach
# Processing Record 21 of Set 7 | grootfontein
# Processing Record 22 of Set 7 | comodoro rivadavia
# Processing Record 23 of Set 7 | yinchuan
# Processing Record 24 of Set 7 | tumut
# Processing Record 25 of Set 7 | tautira
# Processing Record 26 of Set 7 | vila velha
# Processing Record 27 of Set 7 | dingle
# Processing Record 28 of Set 7 | katsuura
# Processing Record 29 of Set 7 | uturoa
# Processing Record 30 of Set 7 | ballina
# Processing Record 31 of Set 7 | harnosand
# Processing Record 32 of Set 7 | ostersund
# Processing Record 33 of Set 7 | santa cruz del sur
# Processing Record 34 of Set 7 | cabo rojo
# Processing Record 35 of Set 7 | pont-audemer
# Processing Record 36 of Set 7 | manoel urbano
# Processing Record 37 of Set 7 | houston
# Processing Record 38 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 7 | merauke
# Processing Record 40 of Set 7 | puerto baquerizo moreno
# Processing Record 41 of Set 7 | sembakung
# Processing Record 42 of Set 7 | karasjok
# Processing Record 43 of Set 7 | masalli
# Processing Record 44 of Set 7 | kirakira
# Processing Record 45 of Set 7 | lompoc
# Processing Record 46 of Set 7 | aksu
# Processing Record 47 of Set 7 | sydney
# Processing Record 48 of Set 7 | wagar
# Processing Record 49 of Set 7 | mbanza-ngungu
# Processing Record 50 of Set 7 | san luis
# Processing Record 1 of Set 8 | pangnirtung
# Processing Record 2 of Set 8 | kuminskiy
# Processing Record 3 of Set 8 | elin pelin
# Processing Record 4 of Set 8 | bereznik
# Processing Record 5 of Set 8 | inuvik
# Processing Record 6 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 8 | quelimane
# Processing Record 8 of Set 8 | lodja
# Processing Record 9 of Set 8 | ambajogai
# Processing Record 10 of Set 8 | geraldton
# Processing Record 11 of Set 8 | chumphon
# Processing Record 12 of Set 8 | norsup
# Processing Record 13 of Set 8 | cabedelo
# Processing Record 14 of Set 8 | shillong
# Processing Record 15 of Set 8 | gurupa
# Processing Record 16 of Set 8 | dongsheng
# Processing Record 17 of Set 8 | sidi bin nur
# Processing Record 18 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 8 | turan
# Processing Record 20 of Set 8 | linxia
# Processing Record 21 of Set 8 | teluk nibung
# Processing Record 22 of Set 8 | iquique
# Processing Record 23 of Set 8 | pandan
# Processing Record 24 of Set 8 | mae chan
# Processing Record 25 of Set 8 | madina
# Processing Record 26 of Set 8 | mackenzie
# Processing Record 27 of Set 8 | aksha
# Processing Record 28 of Set 8 | namatanai
# Processing Record 29 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 30 of Set 8 | longyearbyen
# Processing Record 31 of Set 8 | surin
# Processing Record 32 of Set 8 | policoro
# Processing Record 33 of Set 8 | port blair
# Processing Record 34 of Set 8 | saint-georges
# Processing Record 35 of Set 8 | sagua la grande
# Processing Record 36 of Set 8 | sao desiderio
# Processing Record 37 of Set 8 | ugoofaaru
# Processing Record 38 of Set 8 | glace bay
# Processing Record 39 of Set 8 | hukuntsi
# Processing Record 40 of Set 8 | hoquiam
# Processing Record 41 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 42 of Set 8 | astana
# Processing Record 43 of Set 8 | sembe
# Processing Record 44 of Set 8 | shediac
# Processing Record 45 of Set 8 | jacareacanga
# Processing Record 46 of Set 8 | okhotsk
# Processing Record 47 of Set 8 | noumea
# Processing Record 48 of Set 8 | mecca
# Processing Record 49 of Set 8 | cockburn town
# Processing Record 50 of Set 8 | marawi
# Processing Record 1 of Set 9 | tual
# Processing Record 2 of Set 9 | veselynove
# Processing Record 3 of Set 9 | vostok
# Processing Record 4 of Set 9 | qasigiannguit
# Processing Record 5 of Set 9 | inta
# Processing Record 6 of Set 9 | xining
# Processing Record 7 of Set 9 | minatitlan
# Processing Record 8 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 9 | takoradi
# Processing Record 10 of Set 9 | luckenwalde
# Processing Record 11 of Set 9 | gravdal
# Processing Record 12 of Set 9 | college
# Processing Record 13 of Set 9 | palmerston
# Processing Record 14 of Set 9 | boa vista
# Processing Record 15 of Set 9 | nkhotakota
# Processing Record 16 of Set 9 | erice
# Processing Record 17 of Set 9 | abalak
# Processing Record 18 of Set 9 | wajima
# Processing Record 19 of Set 9 | aktas
# Processing Record 20 of Set 9 | tessalit
# Processing Record 21 of Set 9 | veraval
# Processing Record 22 of Set 9 | nouadhibou
# Processing Record 23 of Set 9 | boueni
# Processing Record 24 of Set 9 | dunedin
# Processing Record 25 of Set 9 | trairi
# Processing Record 26 of Set 9 | tolaga bay
# Processing Record 27 of Set 9 | atasu
# Processing Record 28 of Set 9 | auki
# Processing Record 29 of Set 9 | kloulklubed
# Processing Record 30 of Set 9 | bathsheba
# Processing Record 31 of Set 9 | hjelset
# Processing Record 32 of Set 9 | merrill
# Processing Record 33 of Set 9 | seymchan
# Processing Record 34 of Set 9 | dutlwe
# Processing Record 35 of Set 9 | crato
# Processing Record 36 of Set 9 | santa barbara
# Processing Record 37 of Set 9 | eyl
# Processing Record 38 of Set 9 | yangambi
# Processing Record 39 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 40 of Set 9 | kenai
# Processing Record 41 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 42 of Set 9 | buraydah
# Processing Record 43 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 44 of Set 9 | tuatapere
# Processing Record 45 of Set 9 | kamyaran
# Processing Record 46 of Set 9 | malanje
# Processing Record 47 of Set 9 | turukhansk
# Processing Record 48 of Set 9 | mamallapuram
# Processing Record 49 of Set 9 | palana
# Processing Record 50 of Set 9 | torbay
# Processing Record 1 of Set 10 | high level
# Processing Record 2 of Set 10 | san carlos de bariloche
# Processing Record 3 of Set 10 | sault sainte marie
# Processing Record 4 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 10 | kavieng
# Processing Record 6 of Set 10 | alyangula
# Processing Record 7 of Set 10 | chapais
# Processing Record 8 of Set 10 | zhezkazgan
# Processing Record 9 of Set 10 | anta
# Processing Record 10 of Set 10 | havoysund
# Processing Record 11 of Set 10 | fare
# Processing Record 12 of Set 10 | tombouctou
# Processing Record 13 of Set 10 | sarh
# Processing Record 14 of Set 10 | coruripe
# Processing Record 15 of Set 10 | bambous virieux
# Processing Record 16 of Set 10 | puerto rondon
# Processing Record 17 of Set 10 | tazovskiy
# Processing Record 18 of Set 10 | san isidro
# Processing Record 19 of Set 10 | darhan
# Processing Record 20 of Set 10 | grimma
# Processing Record 21 of Set 10 | teresopolis
# Processing Record 22 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 10 | lerwick
# Processing Record 24 of Set 10 | hebertville
# City not found. Skipping...
# Processing Record 25 of Set 10 | saint-augustin
# Processing Record 26 of Set 10 | bereda
# Processing Record 27 of Set 10 | alice springs
# Processing Record 28 of Set 10 | damghan
# Processing Record 29 of Set 10 | los llanos de aridane
# Processing Record 30 of Set 10 | coquimbo
# Processing Record 31 of Set 10 | arica
# Processing Record 32 of Set 10 | beloha
# Processing Record 33 of Set 10 | aykhal
# Processing Record 34 of Set 10 | meulaboh
# Processing Record 35 of Set 10 | cuamba
# Processing Record 36 of Set 10 | sinjar
# Processing Record 37 of Set 10 | mao
# Processing Record 38 of Set 10 | isfana
# Processing Record 39 of Set 10 | wangkui
# Processing Record 40 of Set 10 | novikovo
# Processing Record 41 of Set 10 | esperance
# Processing Record 42 of Set 10 | inhambane
# Processing Record 43 of Set 10 | thunder bay
# Processing Record 44 of Set 10 | bubaque
# Processing Record 45 of Set 10 | jaumave
# Processing Record 46 of Set 10 | vao
# Processing Record 47 of Set 10 | kiruna
# Processing Record 48 of Set 10 | tilichiki
# Processing Record 49 of Set 10 | takaka
# Processing Record 50 of Set 10 | punta alta
# Processing Record 1 of Set 11 | stornoway
# Processing Record 2 of Set 11 | tunduru
# City not found. Skipping...
# Processing Record 3 of Set 11 | edinet
# Processing Record 4 of Set 11 | richard toll
# City not found. Skipping...
# Processing Record 5 of Set 11 | christchurch
# Processing Record 6 of Set 11 | constitucion
# Processing Record 7 of Set 11 | ijaki
# City not found. Skipping...
# Processing Record 8 of Set 11 | lasa
# Processing Record 9 of Set 11 | simplicio mendes
# Processing Record 10 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 11 | madera
# Processing Record 12 of Set 11 | jibuti
# Processing Record 13 of Set 11 | praia da vitoria
# Processing Record 14 of Set 11 | balaguer
# Processing Record 15 of Set 11 | laguna
# Processing Record 16 of Set 11 | san patricio
# Processing Record 17 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 18 of Set 11 | mount pleasant
# Processing Record 19 of Set 11 | sakakah
# Processing Record 20 of Set 11 | rio grande
# Processing Record 21 of Set 11 | rocha
# Processing Record 22 of Set 11 | kruisfontein
# Processing Record 23 of Set 11 | jinchengjiang
# City not found. Skipping...
# Processing Record 24 of Set 11 | lazaro cardenas
# Processing Record 25 of Set 11 | korla
# Processing Record 26 of Set 11 | saint-fabien
# City not found. Skipping...
# Processing Record 27 of Set 11 | morondava
# Processing Record 28 of Set 11 | westport
# Processing Record 29 of Set 11 | chakrata
# Processing Record 30 of Set 11 | klaksvik
# Processing Record 31 of Set 11 | casper
# Processing Record 32 of Set 11 | kulhudhuffushi
# Processing Record 33 of Set 11 | linfen
# Processing Record 34 of Set 11 | sinazongwe
# Processing Record 35 of Set 11 | inirida
# Processing Record 36 of Set 11 | dudinka
# Processing Record 37 of Set 11 | tocopilla
# Processing Record 38 of Set 11 | sept-iles
# Processing Record 39 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 40 of Set 11 | talcahuano
# Processing Record 41 of Set 11 | ust-tsilma
# Processing Record 42 of Set 11 | san andres
# Processing Record 43 of Set 11 | tarija
# Processing Record 44 of Set 11 | ucluelet
# Processing Record 45 of Set 11 | sawakin
# Processing Record 46 of Set 11 | talara
# Processing Record 47 of Set 11 | boyolangu
# Processing Record 48 of Set 11 | aksarka
# Processing Record 49 of Set 11 | letterkenny
# Processing Record 50 of Set 11 | fort morgan
# Processing Record 1 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 12 | pionerskiy
# Processing Record 3 of Set 12 | ewa beach
# Processing Record 4 of Set 12 | sladkovo
# Processing Record 5 of Set 12 | ossora
# Processing Record 6 of Set 12 | kieta
# Processing Record 7 of Set 12 | moctezuma
# Processing Record 8 of Set 12 | batemans bay
# Processing Record 9 of Set 12 | santa clara
# Processing Record 10 of Set 12 | susaki
# Processing Record 11 of Set 12 | flinders
# Processing Record 12 of Set 12 | mazara del vallo
# Processing Record 13 of Set 12 | ascension
# Processing Record 14 of Set 12 | banikoara
# Processing Record 15 of Set 12 | baruun-urt
# Processing Record 16 of Set 12 | rey bouba
# Processing Record 17 of Set 12 | sao felix do xingu
# Processing Record 18 of Set 12 | komsomolskiy
# Processing Record 19 of Set 12 | port hardy
# Processing Record 20 of Set 12 | liverpool
# Processing Record 21 of Set 12 | urla
# Processing Record 22 of Set 12 | springfield
# Processing Record 23 of Set 12 | la plaine
# Processing Record 24 of Set 12 | winnemucca
# Processing Record 25 of Set 12 | bage
# Processing Record 26 of Set 12 | sinnamary
# Processing Record 27 of Set 12 | oktyabrskiy
# Processing Record 28 of Set 12 | high rock
# Processing Record 29 of Set 12 | abakaliki
# Processing Record 30 of Set 12 | lesozavodsk
# Processing Record 31 of Set 12 | robertsport
# Processing Record 32 of Set 12 | khor
# Processing Record 33 of Set 12 | springdale
# Processing Record 34 of Set 12 | kautokeino
# Processing Record 35 of Set 12 | la paz
# Processing Record 36 of Set 12 | brokopondo
# Processing Record 37 of Set 12 | bombay
# Processing Record 38 of Set 12 | calvia
# Processing Record 39 of Set 12 | larsnes
# Processing Record 40 of Set 12 | zaysan
# Processing Record 41 of Set 12 | port-gentil
# Processing Record 42 of Set 12 | deputatskiy
# Processing Record 43 of Set 12 | yaan
# Processing Record 44 of Set 12 | north las vegas
# Processing Record 45 of Set 12 | garissa
# Processing Record 46 of Set 12 | acapulco
# Processing Record 47 of Set 12 | providencia
# Processing Record 48 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 49 of Set 12 | nalut
# Processing Record 50 of Set 12 | baculin
# Processing Record 1 of Set 13 | acarau
# Processing Record 2 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 13 | san ramon
# Processing Record 4 of Set 13 | yomou
# Processing Record 5 of Set 13 | kutum
# Processing Record 6 of Set 13 | dankov
# Processing Record 7 of Set 13 | kavadarci
# Processing Record 8 of Set 13 | qui nhon
# Processing Record 9 of Set 13 | dongli
# Processing Record 10 of Set 13 | shangzhi
# Processing Record 11 of Set 13 | kidal
# Processing Record 12 of Set 13 | samarai
# Processing Record 13 of Set 13 | xinmin
# Processing Record 14 of Set 13 | mouzakion
# City not found. Skipping...
# Processing Record 15 of Set 13 | fort nelson
# Processing Record 16 of Set 13 | faya
# Processing Record 17 of Set 13 | tahe
# Processing Record 18 of Set 13 | terra santa
# Processing Record 19 of Set 13 | madanapalle
# Processing Record 20 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 21 of Set 13 | salalah
# Processing Record 22 of Set 13 | zandak
# Processing Record 23 of Set 13 | maceio
# Processing Record 24 of Set 13 | sao joao da barra
# Processing Record 25 of Set 13 | porto velho
# Processing Record 26 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 13 | kenora
# Processing Record 28 of Set 13 | hay river
# Processing Record 29 of Set 13 | ahuimanu
# Processing Record 30 of Set 13 | haverfordwest
# Processing Record 31 of Set 13 | hit
# Processing Record 32 of Set 13 | jega
# Processing Record 33 of Set 13 | rivera
# Processing Record 34 of Set 13 | lumsden
# Processing Record 35 of Set 13 | iskateley
# Processing Record 36 of Set 13 | rosamorada
# Processing Record 37 of Set 13 | goderich
# Processing Record 38 of Set 13 | antofagasta
# Processing Record 39 of Set 13 | hasaki
# Processing Record 40 of Set 13 | channel-port aux basques
# Processing Record 41 of Set 13 | san ignacio
# Processing Record 42 of Set 13 | oranjemund
# Processing Record 43 of Set 13 | sioux lookout
# Processing Record 44 of Set 13 | emerald
# Processing Record 45 of Set 13 | viedma
# Processing Record 46 of Set 13 | vieques
# Processing Record 47 of Set 13 | celestun
# Processing Record 48 of Set 13 | sassandra
# Processing Record 49 of Set 13 | akhtanizovskaya
# Processing Record 50 of Set 13 | crestview
# Processing Record 1 of Set 14 | bambanglipuro
# Processing Record 2 of Set 14 | santa cruz de la palma
# Processing Record 3 of Set 14 | mount isa
# Processing Record 4 of Set 14 | kapan
# Processing Record 5 of Set 14 | teeli
# Processing Record 6 of Set 14 | milingimbi
# City not found. Skipping...
# Processing Record 7 of Set 14 | kijang
# Processing Record 8 of Set 14 | zhangye
# Processing Record 9 of Set 14 | bonthe
# Processing Record 10 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 14 | mansa
# Processing Record 12 of Set 14 | biak
# Processing Record 13 of Set 14 | sarakhs
# Processing Record 14 of Set 14 | batyrevo
# Processing Record 15 of Set 14 | wadi maliz
# Processing Record 16 of Set 14 | pauini
# Processing Record 17 of Set 14 | carlos chagas
# Processing Record 18 of Set 14 | halifax
# Processing Record 19 of Set 14 | huilong
# Processing Record 20 of Set 14 | lumeje
# Processing Record 21 of Set 14 | gigmoto
# Processing Record 22 of Set 14 | yar-sale
# Processing Record 23 of Set 14 | jaramana
# City not found. Skipping...
# Processing Record 24 of Set 14 | bukachacha
# Processing Record 25 of Set 14 | pasighat
# Processing Record 26 of Set 14 | barcelos
# Processing Record 27 of Set 14 | manthani
# Processing Record 28 of Set 14 | kerouane
# Processing Record 29 of Set 14 | jiuquan
# Processing Record 30 of Set 14 | muriwai beach
# Processing Record 31 of Set 14 | vardo
# Processing Record 32 of Set 14 | morehead
# Processing Record 33 of Set 14 | sibu
# Processing Record 34 of Set 14 | mogadishu
# Processing Record 35 of Set 14 | dulce nombre de culmi
# Processing Record 36 of Set 14 | florencia
# Processing Record 37 of Set 14 | magan
# Processing Record 38 of Set 14 | mitsamiouli
# Processing Record 39 of Set 14 | warwick
# Processing Record 40 of Set 14 | yelan-kolenovskiy
# Processing Record 41 of Set 14 | searcy
# Processing Record 42 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 43 of Set 14 | monte alegre
# Processing Record 44 of Set 14 | la serena
# Processing Record 45 of Set 14 | arman
# Processing Record 46 of Set 14 | velikie luki
# City not found. Skipping...
# Processing Record 47 of Set 14 | beringovskiy
# Processing Record 48 of Set 14 | broome
# Processing Record 49 of Set 14 | baishishan
# Processing Record 50 of Set 14 | svetlogorsk
# Processing Record 1 of Set 15 | sorong
# Processing Record 2 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 3 of Set 15 | soanierana ivongo
# Processing Record 4 of Set 15 | san miguel
# Processing Record 5 of Set 15 | mattru
# Processing Record 6 of Set 15 | helena
# Processing Record 7 of Set 15 | olinda
# Processing Record 8 of Set 15 | ancud
# Processing Record 9 of Set 15 | rock sound
# Processing Record 10 of Set 15 | aktash
# Processing Record 11 of Set 15 | port-cartier
# Processing Record 12 of Set 15 | prince rupert
# Processing Record 13 of Set 15 | rabo de peixe
# Processing Record 14 of Set 15 | muzhi
# Processing Record 15 of Set 15 | lanxi
# Processing Record 16 of Set 15 | rudnogorsk
# Processing Record 17 of Set 15 | udarnyy
# Processing Record 18 of Set 15 | harstad
# Processing Record 19 of Set 15 | san lazaro
# Processing Record 20 of Set 15 | neiafu
# Processing Record 21 of Set 15 | salym
# Processing Record 22 of Set 15 | ambon
# Processing Record 23 of Set 15 | pushkinskiye gory
# Processing Record 24 of Set 15 | makambako
# Processing Record 25 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 15 | lahij
# Processing Record 27 of Set 15 | malmyzh
# Processing Record 28 of Set 15 | emmett
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 662

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Port Alfred -33.5906   26.8910     67.17        94          32        4.00
# 1         Atar  20.5169  -13.0499     73.09        19          90        8.66
# 2       Ixtapa  20.7000 -105.2000     76.23        65           0       11.50
# 3       Kupang -10.1667  123.5833     78.62        86         100       20.85
# 4  Honningsvag  70.9821   25.9704     37.15        87          75       21.85
# 5     Havelock  34.8791  -76.9013     57.18        76          89        5.23
# 6         Poum -20.2333  164.0167     79.36        81          95        7.96
# 7   Bredasdorp -34.5322   20.0403     66.29        75           7        9.84
# 8     Ngunguru -35.6167  174.5000     66.00        86          98       10.25
# 9     Hermanus -34.4187   19.2345     66.79        79           0       12.50
#
#   Country       Description
# 0      ZA  scattered clouds
# 1      MR   overcast clouds
# 2      MX         clear sky
# 3      ID   overcast clouds
# 4      NO     broken clouds
# 5      US   overcast clouds
# 6      NC   overcast clouds
# 7      ZA         clear sky
# 8      NZ   overcast clouds
# 9      ZA         clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:

# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Port Alfred      ZA -33.5906   26.8910     67.17        94
# 1                 Atar      MR  20.5169  -13.0499     73.09        19
# 2               Ixtapa      MX  20.7000 -105.2000     76.23        65
# 3               Kupang      ID -10.1667  123.5833     78.62        86
# 4          Honningsvag      NO  70.9821   25.9704     37.15        87
# ..                 ...     ...      ...       ...       ...       ...
# 657  Pushkinskiye Gory      RU  57.0209   28.9103     20.17        93
# 658          Makambako      TZ  -8.8453   34.8230     59.92        95
# 659              Lahij      YE  13.1667   44.5833     70.50        83
# 660            Malmyzh      RU  56.5205   50.6818     33.75        98
# 661             Emmett      US  43.8735 -116.4993     42.21        73
#
#      Cloudiness  Wind Speed       Description
# 0            32        4.00  scattered clouds
# 1            90        8.66   overcast clouds
# 2             0       11.50         clear sky
# 3           100       20.85   overcast clouds
# 4            75       21.85     broken clouds
# ..          ...         ...               ...
# 657         100        9.15        light snow
# 658         100        3.60        light rain
# 659          13        5.95        few clouds
# 660         100       17.07   overcast clouds
# 661         100        1.99   overcast clouds
#
# [662 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
